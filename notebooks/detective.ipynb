# %%
import pandas as pd
import os

# %%
GENRE = 'detective'
dir_path = f'../data/{GENRE}/'

all_entries = os.listdir(dir_path)
filenames = []

for entry in all_entries:
    full_path = os.path.join(dir_path, entry)
    if os.path.isfile(full_path):
        filenames.append(entry)

# %%
dataframes = []

for f in filenames:
    df = pd.read_csv(dir_path+f)
    dataframes.append(df)
    
final_df = pd.concat(dataframes, axis=0, ignore_index=True)

# %%
final_df
# Out:
#                                   author                           title  \
# 0                             Гаан Лилия    В старой, но недоброй Англии
# 1                      Александра Ланина           Злотов. Охота на беса
# 2                        Tatjana Rensink                Правильный выбор
# 3                         Елена Елисеева                      Дорога сна
# 4                        Мария Пилипенко                 Меня зовут Тибо
# ...                                  ...                             ...
# 4782                            Zifferot  Дебют. Иллюзия справедливости.
# 4783  Кристина Выборнова (Аделя Хильман)                    Тайны Колина
# 4784  Кристина Выборнова (Аделя Хильман)                        На слуху
# 4785                       Игорь Яковлев                 Самолет до Кубы
# 4786                       Роман Абрамов      Преступление без наказания
#
#                                              annotation  \
# 0     Оставшись вследствии смерти матери и несчастно...
# 1     Когда-то князя Арсения Злотова сослали на Кавк...
# 2     БЕСПЛАТНО!!!☀️❤️(не забывайте радовать автора ...
# 3     «Есть вещи, которые будет не жалко забыть. И е...
# 4     Психологическая драма с элементами детектива.\...
# ...                                                 ...
# 4782  Фанфик по мультфильму "Зверополис". В жизни Ни...
# 4783  Очередной рассказ-фрагмент из цикла о жизни Ко...
# 4784  У капитана Колина Розанова - полоса неудач. Де...
# 4785  Грабители ворвались в здание банка, прихватив ...
# 4786  Короткий рассказ о преступлении, оставшемся бе...
#
#                                                 img_url  \
# 0     https://rust.litnet.com/uploads/covers/120/173...
# 1     https://rust.litnet.com/uploads/covers/120/173...
# 2     https://rust.litnet.com/uploads/covers/120/171...
# 3     https://rust.litnet.com/uploads/covers/120/171...
# 4     https://rust.litnet.com/uploads/covers/120/170...
# ...                                                 ...
# 4782  https://rust.litnet.com/uploads/covers/120/151...
# 4783  https://rust.litnet.com/uploads/covers/120/150...
# 4784  https://rust.litnet.com/uploads/covers/120/150...
# 4785  https://rust.litnet.com/uploads/covers/120/150...
# 4786  https://rust.litnet.com/uploads/covers/120/150...
#
#                                                book_url  \
# 0     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 1     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 2     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 3     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 4     https://litnet.com/ru/book/v-staroi-no-nedobro...
# ...                                                 ...
# 4782  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4783  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4784  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4785  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4786  https://litnet.com/ru/book/richard-kasl-cikl-z...
#
#                                  genre
# 0     Детективы, Исторический детектив
# 1     Детективы, Исторический детектив
# 2     Детективы, Исторический детектив
# 3     Детективы, Исторический детектив
# 4     Детективы, Исторический детектив
# ...                                ...
# 4782   Детективы, Полицейский детектив
# 4783   Детективы, Полицейский детектив
# 4784   Детективы, Полицейский детектив
# 4785   Детективы, Полицейский детектив
# 4786   Детективы, Полицейский детектив
#
# [4787 rows x 6 columns]

# %%
final_df.to_csv(f'{GENRE}.csv')

# %%
test_df = pd.read_csv(f'./{GENRE}.csv')
test_df
# Out:
#       Unnamed: 0                              author  \
# 0              0                          Гаан Лилия
# 1              1                   Александра Ланина
# 2              2                     Tatjana Rensink
# 3              3                      Елена Елисеева
# 4              4                     Мария Пилипенко
# ...          ...                                 ...
# 4782        4782                            Zifferot
# 4783        4783  Кристина Выборнова (Аделя Хильман)
# 4784        4784  Кристина Выборнова (Аделя Хильман)
# 4785        4785                       Игорь Яковлев
# 4786        4786                       Роман Абрамов
#
#                                title  \
# 0       В старой, но недоброй Англии
# 1              Злотов. Охота на беса
# 2                   Правильный выбор
# 3                         Дорога сна
# 4                    Меня зовут Тибо
# ...                              ...
# 4782  Дебют. Иллюзия справедливости.
# 4783                    Тайны Колина
# 4784                        На слуху
# 4785                 Самолет до Кубы
# 4786      Преступление без наказания
#
#                                              annotation  \
# 0     Оставшись вследствии смерти матери и несчастно...
# 1     Когда-то князя Арсения Злотова сослали на Кавк...
# 2     БЕСПЛАТНО!!!☀️❤️(не забывайте радовать автора ...
# 3     «Есть вещи, которые будет не жалко забыть. И е...
# 4     Психологическая драма с элементами детектива.\...
# ...                                                 ...
# 4782  Фанфик по мультфильму "Зверополис". В жизни Ни...
# 4783  Очередной рассказ-фрагмент из цикла о жизни Ко...
# 4784  У капитана Колина Розанова - полоса неудач. Де...
# 4785  Грабители ворвались в здание банка, прихватив ...
# 4786  Короткий рассказ о преступлении, оставшемся бе...
#
#                                                 img_url  \
# 0     https://rust.litnet.com/uploads/covers/120/173...
# 1     https://rust.litnet.com/uploads/covers/120/173...
# 2     https://rust.litnet.com/uploads/covers/120/171...
# 3     https://rust.litnet.com/uploads/covers/120/171...
# 4     https://rust.litnet.com/uploads/covers/120/170...
# ...                                                 ...
# 4782  https://rust.litnet.com/uploads/covers/120/151...
# 4783  https://rust.litnet.com/uploads/covers/120/150...
# 4784  https://rust.litnet.com/uploads/covers/120/150...
# 4785  https://rust.litnet.com/uploads/covers/120/150...
# 4786  https://rust.litnet.com/uploads/covers/120/150...
#
#                                                book_url  \
# 0     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 1     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 2     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 3     https://litnet.com/ru/book/v-staroi-no-nedobro...
# 4     https://litnet.com/ru/book/v-staroi-no-nedobro...
# ...                                                 ...
# 4782  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4783  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4784  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4785  https://litnet.com/ru/book/richard-kasl-cikl-z...
# 4786  https://litnet.com/ru/book/richard-kasl-cikl-z...
#
#                                  genre
# 0     Детективы, Исторический детектив
# 1     Детективы, Исторический детектив
# 2     Детективы, Исторический детектив
# 3     Детективы, Исторический детектив
# 4     Детективы, Исторический детектив
# ...                                ...
# 4782   Детективы, Полицейский детектив
# 4783   Детективы, Полицейский детектив
# 4784   Детективы, Полицейский детектив
# 4785   Детективы, Полицейский детектив
# 4786   Детективы, Полицейский детектив
#
# [4787 rows x 7 columns]
